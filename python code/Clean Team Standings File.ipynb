# %% [markdown]
# # Cleaning NFL Team Standings for 2021 - 2022 Season

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#read in csv file
standing = pd.read_csv("Standing.2021.csv")
standing.head()
# Out:
#    SeasonType  Season Conference Division Team                  Name  Wins  \
# 0           1    2021        AFC     East  BUF         Buffalo Bills    11
# 1           1    2021        AFC     East   NE  New England Patriots    10
# 2           1    2021        AFC     East  MIA        Miami Dolphins     9
# 3           1    2021        AFC     East  NYJ         New York Jets     4
# 4           1    2021        AFC    North  CIN    Cincinnati Bengals    10
#
#    Losses  Ties  Percentage  ...  Touchdowns  DivisionWins  DivisionLosses  \
# 0       6     0       0.647  ...          57             5               1
# 1       7     0       0.588  ...          51             3               3
# 2       8     0       0.529  ...          39             4               2
# 3      13     0       0.235  ...          36             0               6
# 4       7     0       0.588  ...          54             4               2
#
# ...

# %%
#create new dataframe with just season standings (exclude pre-season and post-season)
season = standing[standing["SeasonType"] == 1]
season.head()
# Out:
#    SeasonType  Season Conference Division Team                  Name  Wins  \
# 0           1    2021        AFC     East  BUF         Buffalo Bills    11
# 1           1    2021        AFC     East   NE  New England Patriots    10
# 2           1    2021        AFC     East  MIA        Miami Dolphins     9
# 3           1    2021        AFC     East  NYJ         New York Jets     4
# 4           1    2021        AFC    North  CIN    Cincinnati Bengals    10
#
#    Losses  Ties  Percentage  ...  Touchdowns  DivisionWins  DivisionLosses  \
# 0       6     0       0.647  ...          57             5               1
# 1       7     0       0.588  ...          51             3               3
# 2       8     0       0.529  ...          39             4               2
# 3      13     0       0.235  ...          36             0               6
# 4       7     0       0.588  ...          54             4               2
#
# ...

# %%
#create new column concatenating record for labeling purposes
columns = ['Wins', 'Losses', 'Ties']
season['Record'] = season[columns].apply(lambda row: ' - '.join(row.values.astype(str)), axis=1)
season.head()
# Out:
# <ipython-input-21-3cbcdd7ddc8c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['Record'] = season[columns].apply(lambda row: ' - '.join(row.values.astype(str)), axis=1)
#    SeasonType  Season Conference Division Team                  Name  Wins  \
# 0           1    2021        AFC     East  BUF         Buffalo Bills    11
# 1           1    2021        AFC     East   NE  New England Patriots    10
# 2           1    2021        AFC     East  MIA        Miami Dolphins     9
# 3           1    2021        AFC     East  NYJ         New York Jets     4
# 4           1    2021        AFC    North  CIN    Cincinnati Bengals    10
#
#    Losses  Ties  Percentage  ...  DivisionWins  DivisionLosses  \
# ...

# %%
#export cleaned season dataframe
season.to_excel(r'C:\Users\leand\Downloads\Season Record.xlsx', sheet_name='Season', index = False)
